# %%
# the first line of code

# %%
# practicing databricks GitHub integration.

# %%
databricks_fine_grain_tokens

These token are been created to practise the github Databricks integration. the token are fine-grain token accessible to only repo - dbr_fe on 23th April 2026.
